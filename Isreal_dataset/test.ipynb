# %%
from youtube_transcript_api import YouTubeTranscriptApi as yt

reviews = yt.get_transcript("enR58PYHaWw")

print(reviews)
# Out:
# [{'text': '- All right, so today I got a hold of', 'start': 0.18, 'duration': 1.5}, {'text': 'and got to poke around the new iPhone 15', 'start': 1.68, 'duration': 2.55}, {'text': 'and the iPhone 15 Pros.', 'start': 4.23, 'duration': 1.71}, {'text': "I do remember flying here and I'm thinking", 'start': 5.94, 'duration': 1.92}, {'text': 'what could Apple possibly do?', 'start': 7.86, 'duration': 1.44}, {'text': 'Like what could they possibly\nintroduce with a new iPhone,', 'start': 9.3, 'duration': 2.34}, {'text': "the 23rd iPhone that's\nactually interesting?", 'start': 11.64, 'duration': 2.82}, {'text': 'Now, there is more stuff', 'start': 14.46, 'duration': 0.9}, {'text': 'than just the iPhone that was mentioned', 'start': 15.36, 'duration': 1.74}, {'text': 'at this Wonderlust event that Apple hosted', 'start': 17.1, 'duration': 2.61}, {'text': 'including some stuff that straight up', 'start': 19.71, 'duration': 1.2}, {'text': "wasn't mentioned on stage at\nall, so we'll get to that.", 'start': 20.91, 'duration': 3.57}, {'text': 'But this is just the new iPhone stuff.', 'start': 24.48, 'duration': 1.29}, {'text': 'So stay tuned and get\nsubscribed to see the rest.', 'start': 25.77, 'duration': 1.92}, {'text': "But let's just talk about\nthe new iPhone 15 and 15 Pro.", 'start': 27.69, 'duration': 2.88}, {'text': "So here's a lens to look\nat all this stuff through.", 'start': 30.57, 'duration': 2.04}, {'text': 'Coming into this, basically\neverything Apple just added', 'start': 32.61, 'duration': 2.43}, {'text': 'to their newest flagship\nphones falls into two buckets.', 'start': 35.04, 'duration': 3.09}, {'text': "It's either something we've already seen", 'start': 38.13, 'duration': 2.13}, {'text': 'in some other phone for years,', 'start': 40.26, 'duration': 1.74}, {'text': "or it's some ecosystem feature", 'start': 42.0, 'duration': 2.49}, {'text': 'that only works with other iPhones,', 'start': 44.49, 'duration': 2.28}, {'text': 'which is not necessarily a bad thing,', 'start': 46.77, 'duration': 1.08}, {'text': "but it's just a lens to\nlook through this stuff at,", 'start': 47.85, 'duration': 2.55}, {'text': 'just to keep an eye on it.', 'start': 50.4, 'duration': 1.08}, {'text': 'So this is the iPhone 15.', 'start': 51.48, 'duration': 2.31}, {'text': "There's the same two sizes, again,", 'start': 53.79, 'duration': 1.2}, {'text': 'iPhone 15 and iPhone 15 Plus.', 'start': 54.99, 'duration': 2.67}, {'text': "And yeah, you know there's\nsome small changes,", 'start': 57.66, 'duration': 2.73}, {'text': 'like the slight soft corner\nradii on the aluminum rails', 'start': 60.39, 'duration': 4.02}, {'text': 'and the one piece glass back', 'start': 64.41, 'duration': 1.71}, {'text': 'fading between a lighter\nand darker version', 'start': 66.12, 'duration': 2.55}, {'text': 'of the same color, like this new pink one.', 'start': 68.67, 'duration': 2.01}, {'text': "It's pretty seamless.", 'start': 70.68, 'duration': 1.35}, {'text': 'Also, satin soft touch backs', 'start': 72.03, 'duration': 1.68}, {'text': 'across the whole lineup instead of glossy.', 'start': 73.71, 'duration': 2.04}, {'text': 'I definitely like that.', 'start': 75.75, 'duration': 1.44}, {'text': 'But the big headlining\nfeature really is its USB now.', 'start': 77.19, 'duration': 4.65}, {'text': 'Lightning is officially dead.', 'start': 81.84, 'duration': 1.47}, {'text': 'These new iPhones are all\nUSB-C across the board.', 'start': 83.31, 'duration': 3.24}, {'text': 'Now on one hand, this is a huge deal,', 'start': 86.55, 'duration': 2.19}, {'text': "like there's only ever\nbeen one port change", 'start': 88.74, 'duration': 2.22}, {'text': 'in the iPhone ever.', 'start': 90.96, 'duration': 1.02}, {'text': 'Back in 2012, it went from\nthat 30-pin connector thing', 'start': 91.98, 'duration': 3.93}, {'text': "to this new lightning thing,\nwhich we've had ever since.", 'start': 95.91, 'duration': 2.55}, {'text': 'And now the second one ever is USB type C.', 'st ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.DataFrame(reviews)
data.head()
# Out:
#                                          text  start  duration
# 0       - All right, so today I got a hold of   0.18      1.50
# 1    and got to poke around the new iPhone 15   1.68      2.55
# 2                     and the iPhone 15 Pros.   4.23      1.71
# 3  I do remember flying here and I'm thinking   5.94      1.92
# 4               what could Apple possibly do?   7.86      1.44
