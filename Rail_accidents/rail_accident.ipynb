# %% [markdown]
# Import Python libraries and packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.express as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Load the data into the data frame

# %%
df = pd.read_csv("C:\\Users\\I355833\\Documents\\data_set\\rail_road\\Rail_Equipment_Accident_Incident_Data.csv")
df.head()
# Out:
#   Reporting Railroad Code                            Reporting Railroad Name  \
# 0                    NICD  Northern Indiana Commuter Transportation District
# 1                    NIRC  NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...
# 2                      CR                                            Conrail
# 3                      IC                  Illinois Central Railroad Company
# 4                      IC                  Illinois Central Railroad Company
#
#    Report Year Accident Number  \
# 0       2017.0        N1700013
# 1       2017.0       201707188
# 2       1981.0         0420001
# 3       2007.0          543854
# 4       2017.0          938223
#
#                                             PDF Link  Accident Year  \
# 0  https://safetydata.fra.dot.gov/Officeofsafety/...           17.0
# 1  https://safetydata.fra.dot.gov/Officeofsafety/...           17.0
# 2  https://safetydata.fra.dot.gov/Officeofsafety/...           81.0
# 3  https://safetydata.fra.dot.gov/Officeofsafety/...            7.0
# 4  https://safetydata.fra.dot.gov/Officeofsafety/...           17.0
#
#    Accident Month Other Railroad Code  \
# 0             6.0                 NaN
# 1             6.0                NICD
# 2             4.0                 NaN
# 3             1.0                 NaN
# 4            10.0                 NaN
#
#                                  Other Railroad Name Other Accident Number  \
# 0                                                NaN                   NaN
# 1  Northern Indiana Commuter Transportation District              N1700013
# 2                                                NaN                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
#
#    ...  Other Railroad SMT Grouping  Other Parent Railroad Company Code  \
# 0  ...                          NaN                                 NaN
# 1  ...            SMT-4 - CP/CN/CCD                                NICD
# 2  ...                          NaN                                 NaN
# 3  ...                          NaN                                 NaN
# 4  ...                          NaN                                 NaN
#
#                   Other Parent Railroad Company Name  \
# 0                                                NaN
# 1  Northern Indiana Commuter Transportation District
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Other Railroad Holding Company Maintenance Railroad Company Grouping  \
# 0                            NaN         Passenger (Formerly Commuter)
# 1                   Not Assigned         Passenger (Formerly Commuter)
# 2                            NaN                                   NaN
# 3                            NaN                              Shippers
# 4                            NaN                                   NaN
#
#    Maintenance Railroad Class  Maintenance Railroad SMT Grouping  \
# 0                     Class 3                  SMT-4 - CP/CN/CCD
# 1                     Class 3                  SMT-4 - CP/CN/CCD
# 2                     Class 3                                NaN
# 3                     Class 3                                NaN
# 4                     Class 1                  SMT-4 - CP/CN/CCD
#
#   Maintenance Parent Railroad Company Code  \
# 0                                     NIRC
# 1                                     NIRC
# 2                                     CRSH
# 3                                     CAEZ
# 4                                       CN
#
#             Maintenance Parent Railroad Company Name  \
# 0  NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...
# 1  NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...
# 2                      Consolidated Rail Corporation
# 3                                   Cargill Elevator
# 4                  Canadian National - North America
#
#   Maintenance Railroad Holding Company
# 0                         Not Assigned
# 1                         Not Assigned
# 2                         Not Assigned
# 3                         Not Assigned
# 4    Canadian National - North America
#
# [5 rows x 160 columns]

# %%
df.shape
# Out:
# (215849, 160)

# %%
df.columns
# Out:
# Index(['Reporting Railroad Code', 'Reporting Railroad Name', 'Report Year',
#        'Accident Number', 'PDF Link', 'Accident Year', 'Accident Month',
#        'Other Railroad Code', 'Other Railroad Name', 'Other Accident Number',
#        ...
#        'Other Railroad SMT Grouping', 'Other Parent Railroad Company Code',
#        'Other Parent Railroad Company Name', 'Other Railroad Holding Company',
#        'Maintenance Railroad Company Grouping', 'Maintenance Railroad Class',
#        'Maintenance Railroad SMT Grouping',
#        'Maintenance Parent Railroad Company Code',
#        'Maintenance Parent Railroad Company Name',
#        'Maintenance Railroad Holding Company'],
#       dtype='object', length=160)
