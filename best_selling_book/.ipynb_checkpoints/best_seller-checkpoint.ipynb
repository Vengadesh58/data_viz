# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("bestsellers.csv",parse_dates=["Year"])

# %%
df.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    datetime64[ns]
#  6   Genre        550 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 30.2+ KB

# %%
df.describe()
# Out:
#        User Rating       Reviews       Price
# count   550.000000    550.000000  550.000000
# mean      4.618364  11953.281818   13.100000
# std       0.226980  11731.132017   10.842262
# min       3.300000     37.000000    0.000000
# 25%       4.500000   4058.000000    7.000000
# 50%       4.700000   8580.000000   11.000000
# 75%       4.800000  17253.250000   16.000000
# max       4.900000  87841.000000  105.000000

# %%
df.select_dtypes("object")
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author        Genre
# 0                    JJ Smith  Non Fiction
# 1                Stephen King      Fiction
# 2          Jordan B. Peterson  Non Fiction
# 3               George Orwell      Fiction
# 4    National Geographic Kids  Non Fiction
# ..                        ...          ...
# 545               Jeff Kinney      Fiction
# 546               Jen Sincero  Non Fiction
# 547               Jen Sincero  Non Fiction
# 548               Jen Sincero  Non Fiction
# 549               Jen Sincero  Non Fiction
#
# [550 rows x 3 columns]

# %%
g = sns.jointplot(data=df,x="Price",y="Year")
g.plot_joint(sns.kdeplot,color='y',zorder=0)
g.plot_marginals(sns.rugplot,color='r',height=-0.2,clip_on=False)

# %%
sns.lmplot(data=df,x="User Rating",y="Price",hue="Genre",col="Genre")

# %%
sns.relplot(data=df,x="Year",y="Price",hue="Genre",kind="line")

# %%
sns.catplot(data=df,x="Genre",y="User Rating",kind="box")

# %%
sns.catplot(data=df,x="Genre",y="User Rating",kind="point",capsize=0.1,hue="Genre")

# %%
df["mean_price_on_year"] = df.groupby("Year")['Price'].transform(lambda x : x.median())

# %%
df[["Year","mean_price_on_year"]].value_counts()
# Out:
# Year        mean_price_on_year
# 2009-01-01  12.0                  50
# 2010-01-01  12.5                  50
# 2011-01-01  13.0                  50
# 2012-01-01  13.0                  50
# 2013-01-01  12.5                  50
# 2014-01-01  10.0                  50
# 2015-01-01  9.0                   50
# 2016-01-01  9.0                   50
# 2017-01-01  9.0                   50
# 2018-01-01  8.0                   50
# 2019-01-01  10.0                  50
# dtype: int64

# %%
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price       Year  \
# 0                  JJ Smith          4.7    17350      8 2016-01-01
# 1              Stephen King          4.6     2052     22 2011-01-01
# 2        Jordan B. Peterson          4.7    18979     15 2018-01-01
# 3             George Orwell          4.7    21424      6 2017-01-01
# 4  National Geographic Kids          4.8     7665     12 2019-01-01
#
#          Genre  mean_price_on_year
# 0  Non Fiction                 9.0
# 1      Fiction                13.0
# 2  Non Fiction                 8.0
# 3      Fiction                 9.0
# 4  Non Fiction                10.0

# %%
df["mean_rating_by_genre"] = df.groupby("Genre")["User Rating"].transform(lambda x : x.median())

# %%
df[["Genre","mean_rating_by_genre"]].value_counts()
# Out:
# Genre        mean_rating_by_genre
# Non Fiction  4.6                     310
# Fiction      4.7                     240
# dtype: int64

# %%
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price       Year  \
# 0                  JJ Smith          4.7    17350      8 2016-01-01
# 1              Stephen King          4.6     2052     22 2011-01-01
# 2        Jordan B. Peterson          4.7    18979     15 2018-01-01
# 3             George Orwell          4.7    21424      6 2017-01-01
# 4  National Geographic Kids          4.8     7665     12 2019-01-01
#
#          Genre  mean_price_on_year  mean_rating_by_genre
# 0  Non Fiction                 9.0                   4.6
# 1      Fiction                13.0                   4.7
# 2  Non Fiction                 8.0                   4.6
# 3      Fiction                 9.0                   4.7
# 4  Non Fiction                10.0                   4.6

# %%
df['Author'].value_counts()
# Out:
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Keith Richards                         1
# Chris Cleave                           1
# Alice Schertle                         1
# Celeste Ng                             1
# Adam Gasiewski                         1
# Name: Author, Length: 248, dtype: int64

# %%
df.describe()
# Out:
#        User Rating       Reviews       Price  mean_price_on_year  \
# count   550.000000    550.000000  550.000000          550.000000
# mean      4.618364  11953.281818   13.100000           10.727273
# std       0.226980  11731.132017   10.842262            1.802695
# min       3.300000     37.000000    0.000000            8.000000
# 25%       4.500000   4058.000000    7.000000            9.000000
# 50%       4.700000   8580.000000   11.000000           10.000000
# 75%       4.800000  17253.250000   16.000000           12.500000
# max       4.900000  87841.000000  105.000000           13.000000
#
#        mean_rating_by_genre
# count            550.000000
# mean               4.643636
# std                0.049639
# min                4.600000
# 25%                4.600000
# 50%                4.600000
# 75%                4.700000
# max                4.700000

# %%
df.memory_usage(deep=True)
# Out:
# Index                     128
# Name                    59737
# Author                  39078
# User Rating              4400
# Reviews                  4400
# Price                    4400
# Year                     4400
# Genre                   36440
# mean_price_on_year       4400
# mean_rating_by_genre     4400
# dtype: int64

# %% [markdown]
# ## outliers and cleaning data

# %%
#identifying the outliers

sevety_fifth = df['Price'].quantile(0.75)
twenty_fifth = df['Price'].quantile(0.25)

iqr = sevety_fifth - twenty_fifth

upper = sevety_fifth + (1.5*iqr)
lower = twenty_fifth - (1.5*iqr)

print(upper,lower)
# Out:
# 29.5 -6.5

# %%
df[(df['Price']< lower) | (df['Price'] > upper)]
# Out:
#                                                   Name  \
# 6    A Game of Thrones / A Clash of Kings / A Storm...
# 12                             A Stolen Life: A Memoir
# 69   Diagnostic and Statistical Manual of Mental Di...
# 70   Diagnostic and Statistical Manual of Mental Di...
# 108  Fifty Shades Trilogy (Fifty Shades of Grey / F...
# 151                           Hamilton: The Revolution
# 153  Harry Potter and the Chamber of Secrets: The I...
# 156  Harry Potter and the Prisoner of Azkaban: The ...
# 159         Harry Potter Paperback Box Set (Books 1-7)
# 271  Publication Manual of the American Psychologic...
# 272  Publication Manual of the American Psychologic...
# 273  Publication Manual of the American Psychologic...
# 274  Publication Manual of the American Psychologic...
# 277 2015-01-01  Non Fiction                 9.0                   4.6
# 278 2016-01-01  Non Fiction                 9.0                   4.6
# 279 2017-01-01  Non Fiction                 9.0                   4.6
# 280 2018-01-01  Non Fiction                 8.0                   4.6
# 338 2014-01-01      Fiction                10.0                   4.7
# 346 2009-01-01  Non Fiction                12.0                   4.6
# 410 2011-01-01      Fiction                13.0                   4.7
# 411 2012-01-01      Fiction                13.0                   4.7
# 439 2010-01-01  Non Fiction                12.5                   4.6
# 440 2011-01-01  Non Fiction                13.0                   4.6
# 441 2012-01-01  Non Fiction                13.0                   4.6
# 442 2013-01-01  Non Fiction                12.5                   4.6
# 443 2014-01-01  Non Fiction                10.0                   4.6
# 444 2016-01-01  Non Fiction                 9.0                   4.6
# 473 2009-01-01      Fiction                12.0                   4.7
# 524 2009-01-01      Fiction                12.0                   4.7

# %%
no_outlier = df[(df['Price'] > lower) & (df['Price'] < upper)]

# %%
no_outlier.describe()
# Out:
#        User Rating       Reviews       Price  mean_price_on_year  \
# count   519.000000    519.000000  519.000000          519.000000
# mean      4.620424  12158.373796   11.104046           10.704239
# std       0.229838  11910.557758    5.802140            1.804301
# min       3.300000     37.000000    0.000000            8.000000
# 25%       4.500000   4247.000000    7.000000            9.000000
# 50%       4.700000   8491.000000   10.000000           10.000000
# 75%       4.800000  17336.500000   15.000000           12.500000
# max       4.900000  87841.000000   28.000000           13.000000
#
#        mean_rating_by_genre
# count            519.000000
# mean               4.644316
# std                0.049724
# min                4.600000
# 25%                4.600000
# 50%                4.600000
# 75%                4.700000
# max                4.700000

# %%
sns.displot(data =df,x='Price',kde=True,rug=True)

# %%
sns.displot(data =no_outlier,x='Price',kde=True,rug=True)

# %% [markdown]
# ## Patterns over time

# %%
df.dtypes
# Out:
# Name                            object
# Author                          object
# User Rating                    float64
# Reviews                          int64
# Price                            int64
# Year                    datetime64[ns]
# Genre                           object
# mean_price_on_year             float64
# mean_rating_by_genre           float64
# dtype: object

# %%
sns.lineplot(data=df,x="Year",y="Price",hue="Genre")
# Out:
# <Axes: xlabel='Year', ylabel='Price'>

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#                       User Rating   Reviews     Price  mean_price_on_year  \
# User Rating              1.000000 -0.001729 -0.133086           -0.233912
# Reviews                 -0.001729  1.000000 -0.109182           -0.195369
# Price                   -0.133086 -0.109182  1.000000            0.146221
# mean_price_on_year      -0.233912 -0.195369  0.146221            1.000000
# mean_rating_by_genre     0.116282  0.280058 -0.182761            0.015174
#
#                       mean_rating_by_genre
# User Rating                       0.116282
# Reviews                           0.280058
# Price                            -0.182761
# mean_price_on_year                0.015174
# mean_rating_by_genre              1.000000

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
sns.pairplot(data=no_outlier,vars=["Price","Year","User Rating"])
plt.show()

# %% [markdown]
# ## KDE

# %%
sns.kdeplot(data=df,x="User Rating",hue="Genre",cut=0,cumulative=True)
plt.show()
