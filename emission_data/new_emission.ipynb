# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Methane_final.csv",index_col=0)
df.head()
# Out:
#    region  country   emissions         type                           segment  \
# 0  Africa  Algeria  257.611206  Agriculture                             Total
# 1  Africa  Algeria    0.052000       Energy                         Bioenergy
# 2  Africa  Algeria  130.798996       Energy  Gas pipelines and LNG facilities
# 3  Africa  Algeria   69.741898       Energy  Gas pipelines and LNG facilities
# 4  Africa  Algeria  213.987000       Energy                       Onshore gas
#
#      reason   baseYear                                              notes
# 0       All  2019-2021  Average based on United Nations Framework Conv...
# 1       All       2022  Estimates from end-uses are for 2020 or 2021 (...
# 2  Fugitive       2022                                      Not available
# 3    Vented       2022                                      Not available
# 4  Fugitive       2022                                      Not available

# %%
india = df[df['country'] == 'India'].reset_index()

# %%
india.head()
# Out:
#    index        region country     emissions         type  \
# 0    481  Asia Pacific   India  18358.517578  Agriculture
# 1    482  Asia Pacific   India   1378.843994       Energy
# 2    483  Asia Pacific   India     89.018600       Energy
# 3    484  Asia Pacific   India    191.925003       Energy
# 4    485  Asia Pacific   India    102.334000       Energy
#
#                             segment    reason   baseYear  \
# 0                             Total       All  2019-2021
# 1                         Bioenergy       All       2022
# 2                       Coking coal       All       2022
# 3  Gas pipelines and LNG facilities  Fugitive       2022
# 4  Gas pipelines and LNG facilities    Vented       2022
#
#                                                notes
# 0  Average based on United Nations Framework Conv...
# 1  Estimates from end-uses are for 2020 or 2021 (...
# 2                                      Not available
# 3                                      Not available
# ...

# %%
india.drop(columns="index",inplace=True)

# %%
sns.heatmap(india.isnull(),yticklabels=False)
# Out:
# <Axes: >

# %%
india.head()
# Out:
#          region country     emissions         type  \
# 0  Asia Pacific   India  18358.517578  Agriculture
# 1  Asia Pacific   India   1378.843994       Energy
# 2  Asia Pacific   India     89.018600       Energy
# 3  Asia Pacific   India    191.925003       Energy
# 4  Asia Pacific   India    102.334000       Energy
#
#                             segment    reason   baseYear  \
# 0                             Total       All  2019-2021
# 1                         Bioenergy       All       2022
# 2                       Coking coal       All       2022
# 3  Gas pipelines and LNG facilities  Fugitive       2022
# 4  Gas pipelines and LNG facilities    Vented       2022
#
#                                                notes
# 0  Average based on United Nations Framework Conv...
# 1  Estimates from end-uses are for 2020 or 2021 (...
# 2                                      Not available
# 3                                      Not available
# ...

# %%
india.columns
# Out:
# Index(['region', 'country', 'emissions', 'type', 'segment', 'reason',
#        'baseYear', 'notes'],
#       dtype='object')
